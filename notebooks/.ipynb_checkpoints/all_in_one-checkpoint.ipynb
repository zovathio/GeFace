# %% [markdown]
# # Preprocessing the database and visualize the classes
#
# In this Notebook we form the informations of the dataset and see which classes exist and each class how many items contain. The result is a valid CSV file with the nessessary informations.

# %%
# Import all packages

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import sys
# %matplotlib inline

# %%
# chdir. it depends on the platform
if sys.platform == 'linux':
    # if os is linux cd to
    project_path = "/home/mate/develop/PycharmProjects/GeFace/"
elif sys.platform is 'windows':
    pass
else:
    pass

os.chdir(project_path)

# %%
try:
    print(os.getcwd())
    # Open CSV with all informations
    csv_file = pd.read_csv("data/imdb.csv",delimiter = ';', encoding = "ISO-8859-1", engine='python')
    pd.set_option('display.max_columns', 100)
except (FileNotFoundError):
    print("CSV file not found")
    current_path = os.getcwd()
    print("Current path is " + current_path)
# Out:
# /home/mate/develop/PycharmProjects/GeFace

# %%
csv_file.head()
# Out:
#     dob  photo_taken                                     full_path  gender  \
# 0  1899         1968   01/nm0000001_rm124825600_1899-5-10_1968.jpg     1.0
# 1  1899         1970  01/nm0000001_rm3343756032_1899-5-10_1970.jpg     1.0
# 2  1899         1968   01/nm0000001_rm577153792_1899-5-10_1968.jpg     1.0
# 3  1899         1968   01/nm0000001_rm946909184_1899-5-10_1968.jpg     1.0
# 4  1899         1968   01/nm0000001_rm980463616_1899-5-10_1968.jpg     1.0
#
#            name                                      face_location face_score  \
# 0  Fred Astaire                [1072.926 161.838 1214.784 303.696]   1.459693
# 1  Fred Astaire                   [477.184 100.352 622.592 245.76]   2.543198
# 2  Fred Astaire  [114.969643089629 114.969643089629 451.6865723...   3.455579
# 3  Fred Astaire  [622.885505642659 424.217503837008 844.3390076...   1.872117
# 4  Fred Astaire  [1013.85900236037 233.882042207585 1201.586127...   1.158766
#
#    second_face_score  celeb_id
# 0           1.118973      6488
# 1           1.852008      6488
# 2           2.985660      6488
# 3                NaN      6488
# 4                NaN      6488

# %%
# Drop all unnessessary infos

df = csv_file.drop(columns=['name', 'face_location','face_score','second_face_score','celeb_id'])

# %%
# Calculate age

df['dob'] = df['photo_taken'] - df['dob']

# %%
# Create age column
df = df.drop(columns=['photo_taken'])
df = df.rename(index=str, columns={"dob": "age"})

# %%
df.head()
# Out:
#    age                                     full_path  gender
# 0   69   01/nm0000001_rm124825600_1899-5-10_1968.jpg     1.0
# 1   71  01/nm0000001_rm3343756032_1899-5-10_1970.jpg     1.0
# 2   69   01/nm0000001_rm577153792_1899-5-10_1968.jpg     1.0
# 3   69   01/nm0000001_rm946909184_1899-5-10_1968.jpg     1.0
# 4   69   01/nm0000001_rm980463616_1899-5-10_1968.jpg     1.0

# %%
# Erase every invalid value
df = df.query('age >= 0 and age <=100')

# %%
try:
    # Write CSV back for laterer use
    df.to_csv("data/dataset.csv",sep = ';')
except(FileNotFoundError):
    print("Couldnt write datas do csv file")
    print(os.getcwd())

# %% [markdown]
# # Visualization of classes

# %%
# Import packages for counting and plotting the histogram
from collections import Counter

# %%
ages = df['age']
age_counts = Counter(ages)

# %%
# Sort ages in increasing order from 0 to 100
df_plot = pd.Series(age_counts).sort_index()
df_plot
# Out:
# 0         47
# 1         65
# 2        221
# 3         71
# 4         58
# 5        145
# 6        226
# 7        283
# 8        567
# 9        809
# 10       932
# 11      1448
# 12      1642
# 13      2178
# 14      2253
# 15      2268
# 16      2835
# 17      3395
# 18      3667
# 19      5045
# 20      7107
# 21      8071
# 22      8202
# 23     10051
# 24     10031
# 25     12916
# 26     11325
# 27     14330
# 28     12622
# 29     15309
#        ...
# 71       977
# 72       963
# 73       685
# 74       652
# 75       558
# 76       655
# 77       558
# 78       450
# 79       439
# 80       321
# 81       313
# 82       257
# 83       159
# 84       211
# 85       133
# 86        97
# 87       118
# 88        97
# 89        34
# 90        56
# 91        42
# 92        13
# 93        14
# 94        24
# 95         4
# 96        15
# 97        11
# 98         1
# 99         3
# 100        4
# Length: 101, dtype: int64

# %%
# Plot classes
df_plot.plot(kind = 'bar',figsize=(30,30), title='Histogram')

# %% [markdown]
# ## Resize images to 128x128
# * Get all the paths of the images from the csv file.
# * create the same structure of directory
# * open images with opencv
# * resize them
# * save in the new directory

# %%
df.head()
# Out:
#    age                                     full_path  gender
# 0   69   01/nm0000001_rm124825600_1899-5-10_1968.jpg     1.0
# 1   71  01/nm0000001_rm3343756032_1899-5-10_1970.jpg     1.0
# 2   69   01/nm0000001_rm577153792_1899-5-10_1968.jpg     1.0
# 3   69   01/nm0000001_rm946909184_1899-5-10_1968.jpg     1.0
# 4   69   01/nm0000001_rm980463616_1899-5-10_1968.jpg     1.0

# %%
image_paths = df.drop(columns=["age", "gender"])
image_paths = image_paths.values

# %%
# create directory structure
try:
    os.mkdir("faces")
    for i in range(100):
        if i < 10:
            os.mkdir("faces/0" + str(i))
        else:
            os.mkdir("faces/" + str(i))
except(FileExistsError):
    pass

# detect faces
# load detector
face_cascade = cv2.CascadeClassifier('detector/haarcascade_frontalface_default.xml')
# eye_cascade = cv2.CascadeClassifier('detector/haarcascade_eye.xml')

min_area = 64*64

# open, resize, save
i = 0
skipp_cntr = 0
for path in image_paths:
    path = path[0]
   
    img = cv2.imread("imdb_crop/" + path)
    area = img.shape[0] * img.shape[1]
    
    # if picture is too small then skipp
    if area <= min_area:
        skipp_cntr += 1
    else:
        #res = cv2.resize(img,(128, 128), interpolation=cv2.INTER_CUBIC)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#         x -= 10
#         y -= 10
#         w += 20
#         h += 20
        for (x,y,w,h) in faces:
            print("{}    {}".format(i, path))
            roi_color = img[y:y+h, x:x+w]
            cv2.imwrite("faces/"+path, roi_color)
            i += 1
        if i is 10:
            break
    
print("skipped",skipp_cntr)
# Out:
# 0    01/nm0000001_rm124825600_1899-5-10_1968.jpg
# 1    01/nm0000001_rm3343756032_1899-5-10_1970.jpg
# 2    01/nm0000001_rm577153792_1899-5-10_1968.jpg
# 3    02/nm0000002_rm1075631616_1924-9-16_1991.jpg
# 4    02/nm0000002_rm1346607872_1924-9-16_2004.jpg
# 5    02/nm0000002_rm1363385088_1924-9-16_2004.jpg
# 6    02/nm0000002_rm1411175936_1924-9-16_1991.jpg
# 7    02/nm0000002_rm1447271168_1924-9-16_2004.jpg
# 8    02/nm0000002_rm1624085760_1924-9-16_2008.jpg
# 9    02/nm0000002_rm1646056960_1924-9-16_1991.jpg
# skipped 0

# %%
# detect faces
# load detector
face_cascade = cv2.CascadeClassifier('detector/haarcascade_frontalface_default.xml')
# eye_cascade = cv2.CascadeClassifier('detector/haarcascade_eye.xml')

min_area = 64*64

# open, resize, save
img = cv2.imread("imdb_crop/01/nm0000101_rm270634496_1952-7-1_1990.jpg")
area = img.shape[0] * img.shape[1]

# if picture is too small then skipp
if area > min_area:

    #res = cv2.resize(img,(128, 128), interpolation=cv2.INTER_CUBIC)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    # if face is too small then skipp
    #     if (w * h) <  (0.25 * area):
    #         skipp_cntr += 1
    #         continue
    x -= 10
    y -= 10
    w += 20
    h += 20
    for (x,y,w,h) in faces:
        print("{}    {}".format(i, path))
        #cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
     #   roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]

#     cv2.imshow("faces/"+path, roi_color)
        plt.imshow(roi_color)
# Out:
# 10    02/nm0000002_rm1646056960_1924-9-16_1991.jpg

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-90b1c362009c> in <module>()
# ----> 1 faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       2 for (x,y,w,h) in faces:
#       3     cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#       4     roi_gray = gray[y:y+h, x:x+w]
#       5     roi_color = img[y:y+h, x:x+w]
#
# NameError: name 'gray' is not defined
