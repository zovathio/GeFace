# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
csv_path = "/home/mate/develop/PycharmProjects/GeFace/faces_model/last/"

# %%
df1 = pd.read_csv(csv_path+"xception_regression_age.csv")
df2 = pd.read_csv(csv_path+"xception_regression_age_fine.csv")

# %%
df1.head()
# Out:
#    epoch_num  val_loss  val_ages_output_loss  val_gender_output_loss  \
# 0          0  0.711021              0.017916                0.693105
# 1          1  0.709552              0.016447                0.693105
# 2          2  0.707067              0.013962                0.693104
# 3          3  0.706613              0.013508                0.693105
# 4          4  0.705428              0.012323                0.693105
#
#    ages_output_acc  gender_output_acc  val_gender_output_acc  \
# 0         0.000016           0.502292               0.512055
# 1         0.000016           0.503315               0.512084
# 2         0.000011           0.502981               0.512257
# 3         0.000022           0.502641               0.512141
# 4         0.000022           0.501023               0.512026
#
#    val_ages_output_acc
# 0             0.000154
# 1             0.000154
# 2             0.000154
# 3             0.000154
# 4             0.000134

# %%
header = list(df1)
REAL_EPOCH = len(df1)
REAL_EPOCH
# Out:
# 10

# %%
losses = ["val_ages_output_loss", "val_gender_output_loss"]
plt.style.use("ggplot")

(fig, ax) = plt.subplots(2, 1, figsize=(8,8))

for (i, l) in enumerate(losses):
    ax[i].set_title("Loss for {}".format(l))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel("Loss")
  
    ax[i].plot(np.arange(0, REAL_EPOCH), df1[l],label=l)
    ax[i].legend()
#     ax[1].set_ylim([-0.01,0.01])
    
#     ax[0].set_ylim([0,1])
    plt.tight_layout()
    plt.savefig(csv_path+"/val_Xceptionloss.png")

# %%
losses = [ "val_loss"]
plt.style.use("ggplot")

(fig, ax) = plt.subplots(2, 1, figsize=(8,8))

for (i, l) in enumerate(losses):
    ax[i].set_title("Loss for {}".format(l))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel("Loss")
  
    ax[i].plot(np.arange(0, REAL_EPOCH), df[l],label=l)
    ax[i].legend()
    
    ax[0].set_ylim([0,1])
    plt.tight_layout()
    plt.savefig(csv_path + "/Xceptionloss.png")

# %%
losses = ["val_ages_output_loss", 
#           "val_gender_output_loss",
         ]


plt.style.use("ggplot")

for (i, l) in enumerate(losses):
    fig = plt.figure(i)
    fig.set_title("{}".format(l))
    fig.set_xlabel("Epochs")
    fig.set_ylabel("{}".format(l))
  
    fig.plot(np.arange(0, REAL_EPOCH), df1[l],label=l)
    fig.legend()
#     ax[1].set_ylim([-0.01,0.01])
    
#     ax[0].set_ylim([0,1])
    plt.tight_layout()
    plt.savefig(csv_path+"/" + l + ".png")
